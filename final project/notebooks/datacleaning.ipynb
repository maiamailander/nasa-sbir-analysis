# %% [markdown]
# First figuring out how to install and implement the right Python environment, ensuring it's active ahead of installing all necessary projects in the workspace.

# %%
python3 -m venv .venv
source .venv/bin/activate
